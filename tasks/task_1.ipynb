# %%
from yargy import Parser, rule, or_
from yargy.pipelines import morph_pipeline
from yargy.predicates import gram, eq, custom

def parse_birth_names(content):

    NAME = rule(
        gram('Name'), 
        gram('Surn') 
    )

    name_parser = Parser(NAME)

    names = set()
    for match in name_parser.findall(content):
        name = " ".join(token.value for token in match.tokens)
        names.add(name)

    return names

def parse_birth_locations(content):

    LOCATION = or_(
        rule(eq('родился'), eq('в'), gram('Geox')),  # "родился в Москве"
        rule(eq('родилась'), eq('в'), gram('Geox')),  # "родилась в Санкт-Петербурге"
        rule(eq('родом'), eq('из'), gram('Geox')),  # "родом из Казани"
        rule(eq('дом'), eq('является'), eq('местом'), eq('рождения'), gram('Geox')),  # "дом является местом рождения Владивосток"
        rule(eq('родной'), eq('город'), eq(':'), gram('Geox'))  # "Родной город: Казань"
    )

    location_parser = Parser(LOCATION)

    locations = set()
    for match in location_parser.findall(content):
        location = " ".join(token.value for token in match.tokens)
        locations.add(location)

    return locations


def parse_birth_dates(content):

    def is_integer(value):
        return value.isdigit() and 1 <= len(value) <= 4

    INTEGER = custom(is_integer)

    MONTHS = morph_pipeline([
        'января', 'февраля', 'марта', 'апреля', 'мая', 'июня',
        'июля', 'августа', 'сентября', 'октября', 'ноября', 'декабря'
    ])

    BIRTH_PREFIX = morph_pipeline([
        'родился', 'родилась', 'дата рождения'
    ])

    BIRTH_DATE = rule(
        BIRTH_PREFIX,
        INTEGER,
        MONTHS,
        INTEGER.optional(),
        eq('года').optional()
    )

    parser = Parser(BIRTH_DATE)

    dates = set()
    for match in parser.findall(content):
        date = " ".join(token.value for token in match.tokens)
        dates.add(date)
    return dates

def process_file(file_path):

    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:

            if not line.strip():
                continue
            
            parts = line.strip().split('\t')
            if len(parts) < 3:
                continue

            rubric, headline, text = parts
            content = f"{headline} {text}"

            names = parse_birth_names(content)
            if not names:
                continue

            locations = parse_birth_locations(content)
            dates = parse_birth_dates(content)

            # 如果日期和地点都为空，跳过
            if not locations and not dates:
                continue

            print(f"Рубрика: {rubric}")
            print(f"Заголовок: {headline}")
            print(f"Имена: {', '.join(names)}")
            print(f"Место рождения: {', '.join(locations) if locations else 'Не найдено'}")
            print(f"Дата рождения: {', '.join(dates) if dates else 'Не найдено'}")
            print()

if __name__ == "__main__":
    file_path = '../data/news.txt'
    process_file(file_path)
# Out:
# Рубрика: culture
# Заголовок: Умер звезда сериала «Закон и порядок»
# Имена: Арнольдом Шварценеггером
# Место рождения: родился в Сиэтле
# Дата рождения: Не найдено
#
# Рубрика: forces
# Заголовок: Путин назначил руководителя главка МВД по борьбе с коррупцией
# Имена: Андрея Курносенко, Дениса Сугробова, Андрей Курносенко, Владимир Путин
# Место рождения: родился в Севастополе
# Дата рождения: Не найдено
#
# Рубрика: culture
# Заголовок: В Артемовске решили демонтировать мемориальную доску Кобзону
# Имена: Иосифу Кобзону, Петр Порошенко, Иосиф Кобзон
# Место рождения: родился в Артемовске
# Дата рождения: Не найдено
#
# Рубрика: culture
# Заголовок: Хиросима наградила Йоко Оно за вклад в искусство
# Имена: Роберт Раушенберг
# Место рождения: родилась в Токио
# Дата рождения: Не найдено
#
# Рубрика: culture
# Заголовок
# Дата рождения: Не найдено
#
# Рубрика: culture
# Заголовок: Посольство РФ в Индонезии подтвердило гибель Владислава Мамышева-Монро
# Имена: Дуни Петровой, Любови Орловой, Владислава Мамышева, Влада Монро, Мэрилин Монро, Тимуром Новиковым
# Место рождения: родился в Ленинграде
# Дата рождения: Не найдено
#
# Рубрика: life
# Заголовок: Серфер из Новой Зеландии спас тонущего принца Дании
# Имена: Мэри Дональдсон
# Место рождения: Не найдено
# Дата рождения: родился 15 октября 2005 года
#
# Рубрика: culture
# Заголовок: Голливудский актер Антон Ельчин погиб в ДТП
# Имена: Антон Ельчин, Виктор Ельчин, Павла Чехова, Ирина Корина, Гарри Поттера
# Место рождения: Не найдено
# Дата рождения: родился 11 марта 1989 года
#
# Рубрика: culture
# Заголовок: Умер писатель Борис Васильев
# Имена: Борис Васильев, Станиславом Ростоцким
# Место рождения: Не найдено
# Дата рождения: родился 21 мая 1924 года
#
# Рубрика: life
# Заголовок: Интернет придумал имя новорожденной канадке
# Имена: Стивен Маклафлин
# Место рождения: Не найдено
# Дата рождения: родившуюся 7 апреля
#
# Рубрика: culture
# Заголовок: Актер Геннадий Венгеров попрощался с друзьями
# Имена: Геннадий Венгеров, Марио Адорф, Ирина Апексимова, Леонид Филатов
# Место рождения: Не найдено
# Дата рождения: Родился 27 августа 1959 года
#
# Рубрика: science
# Заголовок: Умер астронавт Нил Армстронг
# Имена: Нил Армстронг, Олден Армстронг
# Место рождения: Не найдено
# Дата рождения: родился 5 августа 1930 года
#
# Рубрика: culture
# Заголовок: Врачи оценили состояние Льва Дурова как крайне тяжелое
# Имена: Лев Дуров, Леонида Малюгина, Льва Дурова
# Место рождения: Не найдено
# Дата рождения: родился 23 декабря 1931 года
#
# Рубрика: science
# Заголовок: Британский ученый назвал новый наукометрический индекс в честь Ким Кардашян
# Имена: Николь Ричи
# Место рождения: Не найдено
# Дата рождения: родилась 21 октября 1980 года
#
# Рубрика: culture
# Заголовок: В Париже скончалась художница Екатерина Серебрякова
# Имена: Зинаиды Серебряковой, Екатерины Серебряковой, Александр Орлов, Екатерина Серебрякова
# Место рождения: Не найдено
# Дата рождения: родилась 28 июня 1913 года
#
# Рубрика: economics
# Заголовок: Пост президента Standard & Poor's отдали выходцу из Citigroup
# Имена: Дугласа Петерсона
# Место рождения: родился в Индии
# Дата рождения: Не найдено
#
# Рубрика: culture
# Заголовок: Скончался актер Игорь Кваша
# Имена: Игорь Кваша
# Место рождения: родился в Москве
# Дата рождения: Не найдено
#
# Рубрика: media
# Заголовок: Сын Нагиева стал ведущим трэвел-шоу
# Имена: Дмитрия Нагиева
# Место рождения: Не найдено
# Дата рождения: родился 31 августа 1989 года
#
# Рубрика: media
# Заголовок: Московский репортер The Guardian обвинила Reuters в плагиате
# Имена: Мириам Элдер, Полина Жеребцова, Полины Жеребцовой
# Место рождения: родилась в Грозном
# Дата рождения: Не найдено
#
# Рубрика: sport
# Заголовок: Российский чемпион мира будет бесплатно играть в ВХЛ
# Имена: Александр Семин
# Место рождения: родился в Красноярске
# Дата рождения: Не найдено
#
# Рубрика: culture
# Заголовок: Умер автор музыки к «Здравствуйте, я ваша тетя»
# Имена: Бориса Юргенсона, Игоря Казенина, Владислав Казенин
# Место рождения: Не найдено
# Дата рождения: родился 21 мая 1937 года
#
# Рубрика: culture
# Заголовок: Возвращенный из Парижа архив Ремизова показали в Манеже
# Имена: Марк Шагал, Алексея Ремизова, Натальи Резниковой, Пабло Пикассо, Василий Кандинский, Алексей Ремизов
# Место рождения: родился в Москве
# Дата рождения: Не найдено
